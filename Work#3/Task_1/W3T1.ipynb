# %% [markdown]
# 1. Установите MongoDB на локальной машине, а также зарегистрируйтесь в онлайн-сервисе. https://www.mongodb.com/ https://www.mongodb.com/products/compass

# %% [markdown]
# - https://www.mongodb.com/ - Онлайн-сервис MongoDB
# - https://www.mongodb.com/products/compass - MongoDBCompass

# %% [markdown]
# ![mongoDB.png](attachment:mongoDB.png)
